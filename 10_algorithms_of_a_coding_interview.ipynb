# %% [markdown]
# <a href="https://colab.research.google.com/github/JavierMedel/Data-Structures-and-Algorithms/blob/master/10_algorithms_of_a_coding_interview.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# * Depth First Search (No a Tree but I would turn in a Tree)
# * Breadht First Search (difference if a stack of a qeuee)
# * Matching Parenthesis (stacks)
# * Hash Tables (dinamic programing)
# * Variable/Pointers manupulation (longest palindromic)
