# %% [markdown]
# <a href="https://colab.research.google.com/github/JavierMedel/Data-Structures-Algorithms/blob/master/Data_Structures.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Arrays
# * lookup O(1)
# * append O(1)*
# * insert O(n)
# * delete O(n)
#
# *can be O(n)

# %%
string = ['a','b','c','d']

# %%
# append // O(1)
string.append('e') # O(1)
string
# Out:
# ['a', 'b', 'c', 'x', 'd', 'e', 'e', 'e']

# %%
# pop // O(1)
string.pop()
string
# Out:
# ['a', 'b', 'c', 'x', 'd', 'e', 'e']

# %%
# insert  // O(n)
string.insert(3, 'x')
string
# Out:
# ['a', 'b', 'c', 'x', 'd']

# %%
# remove // O(n)
string.remove('c')
string
# Out:
# ['x', 'd', 'e', 'e']

# %% [markdown]
# ## Create our own array

# %%
class MyArray():
  def __init__(self):
    self.length = 0
    self.data = []

  def get(self, index):
    return self.data[index]

  def push(self, item):
    self.data.insert(self.length, item)
    self.length += 1

  def pop(self):
    temp_item = self.length
    del self.data[self.length-1]
    self.length -= self.length

  def delete(self, index):
    temp_item = self.data[index]
    self.shiftItems(index)
    return temp_item
    
  def shiftItems(self, index): # O(n)
    for index in range(self.length-1):
      self.data[index] = self.data[index+1]
    
    del self.data[self.length-1]
    self.length -=1

# %%
myArray = MyArray()

# %%
myArray.push('hello')
myArray.push('you')
myArray.push('!')

# %%
myArray.get(2)
# Out:
# '!'

# %%
myArray.get(0)
# Out:
# 'hello'

# %%
myArray.data
# Out:
# ['hello', 'you', '!']

# %%
myArray.delete(0)
# Out:
# 'you'

# %%
myArray.data
# Out:
# ['!']

# %% [markdown]
# ## Array Questions

# %% [markdown]
# ### Reverse and Array

# %%
string = 'hello! my name is!'

# %%
string.split()[::-1]
# Out:
# ['is!', 'name', 'my', 'hello!']

# %%
def reverse(string=''):
  if type(string) != str:
    print('its no a string')
  elif len(string) < 2:
    print('Small array')
  else:    
    temp_string = []
    for i in range(len(string)):
      temp_string.append(string[(len(string) -1) - i])
    return ''.join(temp_string)

# %%
reverse('[4,5,6,7]')
# Out:
# ']7,6,5,4['

# %% [markdown]
# ### Merge Sorted Arrays
#
# [0,3,4,31] , [4,6,30] = [0,3,4,30,31]

# %%
def mergeSortedArrays(arr1, arr2):
  """
  merge and array function receive 2 paramets
  """

  # the input
  if len(arr1) < 1 or len(arr2) < 1:
    return arr1 + arr2

  mylist=[]
  idx_arr1 =0
  idx_arr2 =0

  while idx_arr1<len(arr1) and idx_arr2<len(arr2):

    if arr1[idx_arr1]<=arr2[idx_arr2]:
      mylist.append(arr1[idx_arr1])
      idx_arr1+=1

    else:
      mylist.append(arr2[idx_arr2])
      idx_arr2+=1

  return mylist+arr1[idx_arr1:]+arr2[idx_arr2:]

# %%
mergeSortedArrays([0,4,5],[1,2,7])
# Out:
# [0, 1, 2, 4, 5, 7]

# %% [markdown]
# # Hash Table (dir)
#
# key : value
#
# - insert O(1)
# - lookup O(1)
# - delete O(1)
# - search O(1)
#
# when you have colitions the reduce in
#
# - O(n / k) -> O(n)
#
# *linked list

# %%
user = {'age' :54,
        'name' :'Kylie',
        'magic' :True}

# %%
user['age']  # O(1)
# Out:
# 54
