# %% [markdown]
# <a href="https://colab.research.google.com/github/JavierMedel/DataStructures_Algorithms/blob/master/firstNonRepeatingCharacter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# find the first character that is repeated in a String

# %%
array = ['a','a','b','c','c','f','g']

# %%
dir_ = {}

# %%
first_element = array[0]

for i in range(0, len(array)):
    if array[i] in dir_:
        dir_[array[i]] = dir_[array[i]] + 1
    else:
        dir_[array[i]] = 1

# %%
for key in dir_:
    if dir_[key] == 1:
        print(key)
        print(dir_[key])
        break
# Out:
# b
# 1

# %%
dir_
# Out:
# {'a': 2, 'b': 1, 'c': 2, 'f': 1, 'g': 1}
